# %% [markdown]
# <a href="https://colab.research.google.com/github/V-S-Swetha/data-visualization/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load the student performance data
df = pd.read_csv('student_performance_data.csv')

# Visualize the distribution of grades using box plots and violin plots
sns.boxplot(x = "grade", showmeans=True, data=df)
plt.xlabel('Grade')
plt.ylabel('Frequency')
plt.title('Distribution of Grades (Box Plot)')
plt.show()

sns.violinplot(x = "grade", showmeans=True, data=df, scale='width')
plt.xlabel('Grade')
plt.ylabel('Frequency')
plt.title('Distribution of Grades (Violin Plot)')
plt.show()

# Explore the relationship between attendance and grades using scatter plots
sns.scatterplot(x='attendance', y='grade', data=df)
plt.xlabel('Attendance (%)')
plt.ylabel('Grade')
plt.title('Attendance vs. Grade')
plt.show()
